# %% [markdown]
# Step.1:

# %%
import os
import shutil

# Define the paths
input_folder = r"C:\Users\User\Desktop\compitission\competition_dataset"  # This is the main folder with the patient folders
output_folder = r"C:\Users\User\Desktop\compitission\1"

# Create the output folder if it doesn't exist
if not os.path.exists(output_folder):
    os.makedirs(output_folder)

# Loop through each patient folder
for patient_id in os.listdir(input_folder):
    patient_folder = os.path.join(input_folder, patient_id)
    
    # Check if it is indeed a folder
    if os.path.isdir(patient_folder):
        
        # Loop through each image file inside the patient folder
        for filename in os.listdir(patient_folder):
            if filename.endswith(".dcm"):
                # Get the mammogram type (RCC, LCC, RMLO, LMLO) from the filename
                mammogram_type = filename.split('.')[0]
                
                # Define the new filename
                new_filename = f"{patient_id}_{mammogram_type}.dcm"
                
                # Source and destination paths
                src = os.path.join(patient_folder, filename)
                dst = os.path.join(output_folder, new_filename)
                
                # Copy and rename the file
                shutil.copy(src, dst)

print("Files have been copied and renamed successfully!")
# Out:
# Files have been copied and renamed successfully!

# %% [markdown]
# Step.2: Converting Dicom to PNG

# %%
import pydicom
from PIL import Image
import numpy as np
import os
import pandas as pd

def dicom_to_png_conversion(dicom_folder, output_folder):
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    # Iterate through all files in the dicom folder
    for root, dirs, files in os.walk(dicom_folder):
        for file in files:
            if file.endswith('.dcm'):
                dicom_path = os.path.join(root, file)
                print(f"Processing file: {dicom_path}")  # Debugging log
                try:
                    # Read DICOM file
                    dicom_data = pydicom.dcmread(dicom_path)
                    pixel_array = dicom_data.pixel_array

                    # Normalize the pixel array
                    pixel_array = pixel_array - np.min(pixel_array)
                    pixel_array = (pixel_array / np.max(pixel_array) * 255).astype(np.uint8)

                    # Convert to 8-bit grayscale image
                    image = Image.fromarray(pixel_array)
                    
                    # Create corresponding folder structure in output folder
                    relative_path = os.path.relpath(root, dicom_folder)
                    output_subfolder = os.path.join(output_folder, relative_path)
                    if not os.path.exists(output_subfolder):
                        os.makedirs(output_subfolder)

                    # Save the image with the same name but PNG extension
                    png_filename = os.path.splitext(file)[0] + ".png"
                    png_path = os.path.join(output_subfolder, png_filename)
                    image.save(png_path)
                    print(f"Saved PNG: {png_path}")  # Debugging log
                except Exception as e:
                    print(f"Error processing file {dicom_path}: {e}")

# Paths for DICOM folders and new PNG output folders
# dicom_folder = r'C:\Users\User\Desktop\Test10\1'
# dicom_folder = output_folder


# New output folders for the PNG files
png_output = r'C:\Users\User\Desktop\compitission\2'

# Convert DICOM to PNG for both Training and Test folders
dicom_to_png_conversion(output_folder, png_output)

print("DICOM to PNG conversion completed.")
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_20720\1796751499.py:5: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd
# Processing file: C:\Users\User\Desktop\compitission\1\20191_RCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\20191_RCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\20191_RMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\20191_RMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\20215_RCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\20215_RCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\20215_RMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\20215_RMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\20465_RCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\20465_RCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\20465_RMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\20465_RMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\20472_RCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\20472_RCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\20472_RMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\20472_RMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\20565_RCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\20565_RCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\20565_RMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\20565_RMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\20667_RCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\20667_RCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\20667_RMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\20667_RMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\21047_LCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\21047_LCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\21047_LMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\21047_LMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\21075_LCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\21075_LCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\21075_LMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\21075_LMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\21123_LCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\21123_LCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\21123_LMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\21123_LMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\21173_LCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\21173_LCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\21173_LMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\21173_LMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\21201_RCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\21201_RCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\21201_RMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\21201_RMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\21229_RCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\21229_RCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\21229_RMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\21229_RMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\21320_LCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\21320_LCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\21320_LMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\21320_LMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\21332_LCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\21332_LCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\21332_LMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\21332_LMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\21753_LCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\21753_LCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\21753_LMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\21753_LMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\21811_LCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\21811_LCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\21811_LMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\21811_LMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\21996_RCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\21996_RCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\21996_RMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\21996_RMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\22038_RCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\22038_RCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\22038_RMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\22038_RMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\22106_RCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\22106_RCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\22106_RMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\22106_RMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\22124_RCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\22124_RCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\22124_RMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\22124_RMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\22208_LCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\22208_LCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\22208_LMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\22208_LMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\22289_RCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\22289_RCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\22289_RMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\22289_RMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\22390_LCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\22390_LCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\22390_LMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\22390_LMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\22444_RCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\22444_RCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\22444_RMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\22444_RMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\22488_LCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\22488_LCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\22488_LMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\22488_LMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\22835_RCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\22835_RCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\22835_RMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\22835_RMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\22915_RCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\22915_RCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\22915_RMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\22915_RMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\23034_LCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\23034_LCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\23034_LMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\23034_LMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\23141_RCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\23141_RCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\23141_RMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\23141_RMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\23176_LCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\23176_LCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\23176_LMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\23176_LMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\23225_RCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\23225_RCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\23225_RMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\23225_RMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\23246_LCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\23246_LCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\23246_LMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\23246_LMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\23299_LCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\23299_LCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\23299_LMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\23299_LMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\23306_RCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\23306_RCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\23306_RMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\23306_RMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\23326_LCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\23326_LCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\23326_LMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\23326_LMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\23327_LCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\23327_LCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\23327_LMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\23327_LMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\23374_RCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\23374_RCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\23374_RMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\23374_RMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\23441_RCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\23441_RCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\23441_RMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\23441_RMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\23581_RCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\23581_RCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\23581_RMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\23581_RMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\23610_LCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\23610_LCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\23610_LMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\23610_LMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\23670_RCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\23670_RCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\23670_RMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\23670_RMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\23767_LCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\23767_LCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\23767_LMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\23767_LMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\23872_RCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\23872_RCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\23872_RMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\23872_RMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\24082_LCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\24082_LCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\24082_LMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\24082_LMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\24094_LCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\24094_LCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\24094_LMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\24094_LMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\24214_LCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\24214_LCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\24214_LMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\24214_LMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\24403_LCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\24403_LCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\24403_LMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\24403_LMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\24490_RCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\24490_RCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\24490_RMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\24490_RMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\24521_LCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\24521_LCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\24521_LMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\24521_LMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\24552_RCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\24552_RCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\24552_RMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\24552_RMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\24621_LCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\24621_LCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\24621_LMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\24621_LMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\24730_RCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\24730_RCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\24730_RMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\24730_RMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\24932_LCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\24932_LCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\24932_LMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\24932_LMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\24938_RCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\24938_RCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\24938_RMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\24938_RMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\25165_RCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\25165_RCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\25165_RMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\25165_RMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\25200_LCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\25200_LCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\25200_LMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\25200_LMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\25504_LCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\25504_LCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\25504_LMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\25504_LMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\25527_LCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\25527_LCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\25527_LMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\25527_LMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\25536_LCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\25536_LCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\25536_LMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\25536_LMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\25739_RCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\25739_RCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\25739_RMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\25739_RMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\25809_LCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\25809_LCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\25809_LMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\25809_LMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\25835_RCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\25835_RCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\25835_RMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\25835_RMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\25842_LCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\25842_LCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\25842_LMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\25842_LMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\25845_LCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\25845_LCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\25845_LMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\25845_LMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\25985_RCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\25985_RCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\25985_RMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\25985_RMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\25992_RCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\25992_RCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\25992_RMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\25992_RMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\26110_RCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\26110_RCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\26110_RMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\26110_RMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\26173_LCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\26173_LCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\26173_LMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\26173_LMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\26235_RCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\26235_RCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\26235_RMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\26235_RMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\26510_RCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\26510_RCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\26510_RMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\26510_RMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\26563_LCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\26563_LCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\26563_LMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\26563_LMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\26739_LCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\26739_LCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\26739_LMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\26739_LMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\26769_RCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\26769_RCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\26769_RMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\26769_RMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\26821_RCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\26821_RCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\26821_RMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\26821_RMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\26890_LCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\26890_LCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\26890_LMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\26890_LMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\26908_RCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\26908_RCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\26908_RMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\26908_RMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\26957_LCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\26957_LCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\26957_LMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\26957_LMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\27028_RCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\27028_RCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\27028_RMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\27028_RMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\27074_LCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\27074_LCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\27074_LMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\27074_LMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\27184_RCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\27184_RCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\27184_RMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\27184_RMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\27337_LCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\27337_LCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\27337_LMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\27337_LMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\27360_LCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\27360_LCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\27360_LMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\27360_LMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\27382_LCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\27382_LCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\27382_LMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\27382_LMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\27497_LCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\27497_LCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\27497_LMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\27497_LMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\27514_LCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\27514_LCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\27514_LMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\27514_LMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\27517_RCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\27517_RCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\27517_RMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\27517_RMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\27948_RCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\27948_RCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\27948_RMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\27948_RMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\28006_LCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\28006_LCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\28006_LMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\28006_LMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\28102_LCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\28102_LCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\28102_LMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\28102_LMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\28215_RCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\28215_RCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\28215_RMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\28215_RMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\28366_LCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\28366_LCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\28366_LMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\28366_LMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\28413_LCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\28413_LCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\28413_LMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\28413_LMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\28921_LCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\28921_LCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\28921_LMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\28921_LMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\29007_LCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\29007_LCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\29007_LMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\29007_LMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\29032_LCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\29032_LCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\29032_LMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\29032_LMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\29061_RCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\29061_RCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\29061_RMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\29061_RMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\29314_LCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\29314_LCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\29314_LMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\29314_LMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\29541_LCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\29541_LCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\29541_LMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\29541_LMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\29597_RCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\29597_RCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\29597_RMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\29597_RMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\30086_RCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\30086_RCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\30086_RMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\30086_RMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\30147_LCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\30147_LCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\30147_LMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\30147_LMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\30243_RCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\30243_RCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\30243_RMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\30243_RMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\30304_LCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\30304_LCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\30304_LMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\30304_LMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\30461_RCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\30461_RCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\30461_RMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\30461_RMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\30517_LCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\30517_LCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\30517_LMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\30517_LMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\30640_LCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\30640_LCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\30640_LMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\30640_LMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\30671_RCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\30671_RCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\30671_RMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\30671_RMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\30743_LCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\30743_LCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\30743_LMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\30743_LMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\30830_RCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\30830_RCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\30830_RMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\30830_RMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\30966_RCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\30966_RCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\30966_RMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\30966_RMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\31110_LCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\31110_LCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\31110_LMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\31110_LMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\31125_RCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\31125_RCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\31125_RMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\31125_RMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\31175_RCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\31175_RCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\31175_RMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\31175_RMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\31183_RCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\31183_RCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\31183_RMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\31183_RMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\31226_RCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\31226_RCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\31226_RMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\31226_RMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\31235_LCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\31235_LCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\31235_LMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\31235_LMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\31247_LCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\31247_LCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\31247_LMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\31247_LMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\31295_LCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\31295_LCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\31295_LMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\31295_LMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\31633_RCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\31633_RCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\31633_RMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\31633_RMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\31642_RCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\31642_RCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\31642_RMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\31642_RMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\31679_RCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\31679_RCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\31679_RMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\31679_RMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\31753_RCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\31753_RCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\31753_RMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\31753_RMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\31862_LCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\31862_LCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\31862_LMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\31862_LMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\32322_LCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\32322_LCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\32322_LMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\32322_LMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\32518_LCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\32518_LCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\32518_LMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\32518_LMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\32665_LCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\32665_LCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\32665_LMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\32665_LMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\32871_RCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\32871_RCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\32871_RMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\32871_RMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\32893_RCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\32893_RCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\32893_RMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\32893_RMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\32928_RCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\32928_RCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\32928_RMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\32928_RMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\33053_RCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\33053_RCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\33053_RMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\33053_RMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\33200_RCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\33200_RCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\33200_RMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\33200_RMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\33420_LCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\33420_LCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\33420_LMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\33420_LMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\33514_LCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\33514_LCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\33514_LMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\33514_LMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\33537_RCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\33537_RCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\33537_RMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\33537_RMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\33710_RCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\33710_RCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\33710_RMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\33710_RMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\33816_RCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\33816_RCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\33816_RMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\33816_RMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\33903_LCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\33903_LCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\33903_LMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\33903_LMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\33977_RCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\33977_RCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\33977_RMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\33977_RMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\34059_LCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\34059_LCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\34059_LMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\34059_LMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\34212_RCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\34212_RCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\34212_RMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\34212_RMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\34264_RCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\34264_RCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\34264_RMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\34264_RMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\34289_LCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\34289_LCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\34289_LMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\34289_LMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\34332_LCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\34332_LCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\34332_LMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\34332_LMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\34525_LCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\34525_LCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\34525_LMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\34525_LMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\34548_RCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\34548_RCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\34548_RMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\34548_RMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\34594_LCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\34594_LCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\34594_LMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\34594_LMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\34614_RCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\34614_RCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\34614_RMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\34614_RMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\34639_RCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\34639_RCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\34639_RMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\34639_RMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\34719_LCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\34719_LCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\34719_LMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\34719_LMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\35058_RCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\35058_RCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\35058_RMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\35058_RMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\35084_RCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\35084_RCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\35084_RMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\35084_RMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\35106_LCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\35106_LCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\35106_LMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\35106_LMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\35146_LCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\35146_LCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\35146_LMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\35146_LMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\35163_RCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\35163_RCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\35163_RMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\35163_RMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\35177_LCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\35177_LCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\35177_LMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\35177_LMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\35371_RCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\35371_RCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\35371_RMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\35371_RMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\35435_RCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\35435_RCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\35435_RMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\35435_RMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\35535_RCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\35535_RCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\35535_RMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\35535_RMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\35578_RCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\35578_RCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\35578_RMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\35578_RMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\35639_LCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\35639_LCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\35639_LMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\35639_LMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\35643_LCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\35643_LCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\35643_LMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\35643_LMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\35743_RCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\35743_RCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\35743_RMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\35743_RMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\35880_RCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\35880_RCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\35880_RMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\35880_RMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\35969_LCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\35969_LCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\35969_LMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\35969_LMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\36001_LCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\36001_LCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\36001_LMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\36001_LMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\36046_RCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\36046_RCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\36046_RMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\36046_RMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\36161_RCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\36161_RCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\36161_RMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\36161_RMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\36206_LCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\36206_LCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\36206_LMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\36206_LMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\36213_LCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\36213_LCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\36213_LMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\36213_LMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\36248_LCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\36248_LCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\36248_LMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\36248_LMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\36364_RCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\36364_RCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\36364_RMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\36364_RMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\36512_RCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\36512_RCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\36512_RMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\36512_RMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\36664_RCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\36664_RCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\36664_RMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\36664_RMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\36701_LCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\36701_LCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\36701_LMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\36701_LMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\36747_RCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\36747_RCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\36747_RMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\36747_RMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\36774_RCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\36774_RCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\36774_RMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\36774_RMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\36792_LCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\36792_LCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\36792_LMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\36792_LMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\36964_RCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\36964_RCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\36964_RMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\36964_RMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\37015_LCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\37015_LCC.png
# ...
# Processing file: C:\Users\User\Desktop\compitission\1\92587_RMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\92587_RMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\92611_LCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\92611_LCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\92611_LMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\92611_LMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\92663_LCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\92663_LCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\92663_LMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\92663_LMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\92692_LCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\92692_LCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\92692_LMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\92692_LMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\92744_LCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\92744_LCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\92744_LMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\92744_LMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\92783_RCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\92783_RCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\92783_RMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\92783_RMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\93054_LCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\93054_LCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\93054_LMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\93054_LMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\93276_RCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\93276_RCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\93276_RMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\93276_RMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\93622_RCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\93622_RCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\93622_RMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\93622_RMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\93624_RCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\93624_RCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\93624_RMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\93624_RMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\93630_RCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\93630_RCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\93630_RMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\93630_RMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\93673_LCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\93673_LCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\93673_LMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\93673_LMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\93831_RCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\93831_RCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\93831_RMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\93831_RMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\93977_RCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\93977_RCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\93977_RMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\93977_RMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\94258_RCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\94258_RCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\94258_RMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\94258_RMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\94317_RCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\94317_RCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\94317_RMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\94317_RMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\94436_RCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\94436_RCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\94436_RMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\94436_RMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\94609_LCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\94609_LCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\94609_LMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\94609_LMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\94651_RCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\94651_RCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\94651_RMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\94651_RMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\94721_LCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\94721_LCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\94721_LMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\94721_LMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\94769_LCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\94769_LCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\94769_LMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\94769_LMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\94794_LCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\94794_LCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\94794_LMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\94794_LMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\94838_LCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\94838_LCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\94838_LMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\94838_LMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\94858_RCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\94858_RCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\94858_RMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\94858_RMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\95024_LCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\95024_LCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\95024_LMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\95024_LMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\95044_LCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\95044_LCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\95044_LMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\95044_LMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\95116_LCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\95116_LCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\95116_LMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\95116_LMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\95187_LCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\95187_LCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\95187_LMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\95187_LMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\95494_RCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\95494_RCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\95494_RMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\95494_RMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\95509_LCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\95509_LCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\95509_LMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\95509_LMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\95559_LCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\95559_LCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\95559_LMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\95559_LMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\95642_LCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\95642_LCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\95642_LMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\95642_LMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\95648_RCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\95648_RCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\95648_RMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\95648_RMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\95856_RCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\95856_RCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\95856_RMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\95856_RMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\95887_RCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\95887_RCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\95887_RMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\95887_RMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\96305_LCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\96305_LCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\96305_LMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\96305_LMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\96329_RCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\96329_RCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\96329_RMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\96329_RMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\96498_RCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\96498_RCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\96498_RMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\96498_RMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\96941_RCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\96941_RCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\96941_RMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\96941_RMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\96958_LCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\96958_LCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\96958_LMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\96958_LMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\96991_RCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\96991_RCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\96991_RMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\96991_RMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\97185_LCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\97185_LCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\97185_LMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\97185_LMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\97320_RCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\97320_RCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\97320_RMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\97320_RMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\97601_LCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\97601_LCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\97601_LMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\97601_LMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\97679_LCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\97679_LCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\97679_LMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\97679_LMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\97806_RCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\97806_RCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\97806_RMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\97806_RMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\97822_RCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\97822_RCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\97822_RMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\97822_RMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\97825_RCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\97825_RCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\97825_RMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\97825_RMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\98214_RCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\98214_RCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\98214_RMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\98214_RMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\98392_RCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\98392_RCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\98392_RMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\98392_RMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\98860_LCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\98860_LCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\98870_RCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\98870_RCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\98870_RMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\98870_RMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\98955_LCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\98955_LCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\98955_LMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\98955_LMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\99110_RCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\99110_RCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\99110_RMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\99110_RMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\99115_LCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\99115_LCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\99115_LMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\99115_LMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\99362_RCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\99362_RCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\99362_RMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\99362_RMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\99394_LCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\99394_LCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\99394_LMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\99394_LMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\99414_LCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\99414_LCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\99414_LMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\99414_LMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\99504_RCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\99504_RCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\99504_RMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\99504_RMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\99540_RCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\99540_RCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\99540_RMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\99540_RMLO.png
# Processing file: C:\Users\User\Desktop\compitission\1\99660_LCC.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\99660_LCC.png
# Processing file: C:\Users\User\Desktop\compitission\1\99660_LMLO.dcm
# Saved PNG: C:\Users\User\Desktop\compitission\2\.\99660_LMLO.png
# DICOM to PNG conversion completed.

# %% [markdown]
# Step.3: Create the mammogram data CSV file

# %%
import os
import pandas as pd
from PIL import Image

def create_csv_from_images(image_folder, output_csv):
    # List to store data for each image
    data = []

    # Iterate through all files in the image folder
    for root, dirs, files in os.walk(image_folder):
        for file in files:
            if file.endswith('.png'):
                # Extract patient ID and mammogram type from the filename
                filename = os.path.splitext(file)[0]
                patient_id, mammogram_type = filename.split('_')
                
                # Get the image size
                image_path = os.path.join(root, file)
                with Image.open(image_path) as img:
                    image_size = img.size  # This gives (width, height)
                
                # Append the information to the list
                data.append({
                    'PatientID': patient_id,
                    'Mammogram Type': mammogram_type,
                    'The size of the image': image_size
                })

    # Create a DataFrame from the data
    df = pd.DataFrame(data)
    
    # Save the DataFrame to a CSV file
    df.to_csv(output_csv, index=False)

    print(f"CSV file has been created successfully: {output_csv}")

# Paths for the PNG images folder and CSV output
image_folder = r'C:\Users\User\Desktop\compitission\2'
output_csv = r'C:\Users\User\Desktop\compitission\CSV_mammogram_data.csv'

# Create the CSV file
create_csv_from_images(image_folder, output_csv)
# Out:
# CSV file has been created successfully: C:\Users\User\Desktop\compitission\CSV_mammogram_data.csv

# %% [markdown]
# Step.4: Negative to Positive

# %%
from PIL import Image
import numpy as np
import os

# Function to determine if an image is negative (white background)
def is_negative(image_array):
    # Assuming white background images will have higher mean pixel values
    mean_pixel_value = np.mean(image_array)
    return mean_pixel_value > 127  # Adjust threshold based on your dataset

# Function to convert negative images to positive
def invert_image(image_array):
    return 255 - image_array  # Invert the image

# Function to process and save the images
def process_images(input_folder, output_folder):
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)
    
    for filename in os.listdir(input_folder):
        if filename.endswith('.jpg') or filename.endswith('.png'):
            # Open the image
            image_path = os.path.join(input_folder, filename)
            image = Image.open(image_path).convert('L')  # Convert to grayscale
            image_array = np.array(image)
            
            # Check if the image is negative
            if is_negative(image_array):
                # Invert the image if it's negative
                image_array = invert_image(image_array)
                print(f"Inverted {filename}")
            else:
                print(f"Kept {filename} as is (positive)")
            
            # Save the processed image
            output_image = Image.fromarray(image_array)
            output_image.save(os.path.join(output_folder, filename))

# Specify input and output folder paths
input_folder = r'C:\Users\User\Desktop\compitission\2'
output_folder = r'C:\Users\User\Desktop\compitission\3'


process_images(input_folder, output_folder)
# Out:
# Kept 20191_RCC.png as is (positive)
# Kept 20191_RMLO.png as is (positive)
# Inverted 20215_RCC.png
# Inverted 20215_RMLO.png
# Inverted 20465_RCC.png
# Inverted 20465_RMLO.png
# Inverted 20472_RCC.png
# Inverted 20472_RMLO.png
# Inverted 20565_RCC.png
# Inverted 20565_RMLO.png
# Inverted 20667_RCC.png
# Inverted 20667_RMLO.png
# Inverted 21047_LCC.png
# Inverted 21047_LMLO.png
# Inverted 21075_LCC.png
# Inverted 21075_LMLO.png
# Inverted 21123_LCC.png
# Inverted 21123_LMLO.png
# Inverted 21173_LCC.png
# Inverted 21173_LMLO.png
# Inverted 21201_RCC.png
# Inverted 21201_RMLO.png
# Inverted 21229_RCC.png
# Inverted 21229_RMLO.png
# Inverted 21320_LCC.png
# Inverted 21320_LMLO.png
# Kept 21332_LCC.png as is (positive)
# Kept 21332_LMLO.png as is (positive)
# Inverted 21753_LCC.png
# Inverted 21753_LMLO.png
# Inverted 21811_LCC.png
# Inverted 21811_LMLO.png
# Inverted 21996_RCC.png
# Inverted 21996_RMLO.png
# Inverted 22038_RCC.png
# Inverted 22038_RMLO.png
# Kept 22106_RCC.png as is (positive)
# Kept 22106_RMLO.png as is (positive)
# Kept 22124_RCC.png as is (positive)
# Kept 22124_RMLO.png as is (positive)
# Inverted 22208_LCC.png
# Inverted 22208_LMLO.png
# Kept 22289_RCC.png as is (positive)
# Kept 22289_RMLO.png as is (positive)
# Kept 22390_LCC.png as is (positive)
# Kept 22390_LMLO.png as is (positive)
# Kept 22444_RCC.png as is (positive)
# Kept 22444_RMLO.png as is (positive)
# Inverted 22488_LCC.png
# Inverted 22488_LMLO.png
# Inverted 22835_RCC.png
# Inverted 22835_RMLO.png
# Inverted 22915_RCC.png
# Inverted 22915_RMLO.png
# Inverted 23034_LCC.png
# Inverted 23034_LMLO.png
# Inverted 23141_RCC.png
# Inverted 23141_RMLO.png
# Kept 23176_LCC.png as is (positive)
# Kept 23176_LMLO.png as is (positive)
# Inverted 23225_RCC.png
# Inverted 23225_RMLO.png
# Inverted 23246_LCC.png
# Inverted 23246_LMLO.png
# Kept 23299_LCC.png as is (positive)
# Kept 23299_LMLO.png as is (positive)
# Inverted 23306_RCC.png
# Inverted 23306_RMLO.png
# Kept 23326_LCC.png as is (positive)
# Kept 23326_LMLO.png as is (positive)
# Kept 23327_LCC.png as is (positive)
# Kept 23327_LMLO.png as is (positive)
# Inverted 23374_RCC.png
# Inverted 23374_RMLO.png
# Inverted 23441_RCC.png
# Inverted 23441_RMLO.png
# Inverted 23581_RCC.png
# Inverted 23581_RMLO.png
# Inverted 23610_LCC.png
# Inverted 23610_LMLO.png
# Inverted 23670_RCC.png
# Inverted 23670_RMLO.png
# Kept 23767_LCC.png as is (positive)
# Kept 23767_LMLO.png as is (positive)
# Inverted 23872_RCC.png
# Inverted 23872_RMLO.png
# Kept 24082_LCC.png as is (positive)
# Kept 24082_LMLO.png as is (positive)
# Inverted 24094_LCC.png
# Inverted 24094_LMLO.png
# Inverted 24214_LCC.png
# Inverted 24214_LMLO.png
# Inverted 24403_LCC.png
# Inverted 24403_LMLO.png
# Inverted 24490_RCC.png
# Inverted 24490_RMLO.png
# Kept 24521_LCC.png as is (positive)
# Kept 24521_LMLO.png as is (positive)
# Inverted 24552_RCC.png
# Inverted 24552_RMLO.png
# Inverted 24621_LCC.png
# Inverted 24621_LMLO.png
# Inverted 24730_RCC.png
# Inverted 24730_RMLO.png
# Inverted 24932_LCC.png
# Inverted 24932_LMLO.png
# Inverted 24938_RCC.png
# Inverted 24938_RMLO.png
# Inverted 25165_RCC.png
# Inverted 25165_RMLO.png
# Inverted 25200_LCC.png
# Inverted 25200_LMLO.png
# Inverted 25504_LCC.png
# Inverted 25504_LMLO.png
# Inverted 25527_LCC.png
# Inverted 25527_LMLO.png
# Inverted 25536_LCC.png
# Inverted 25536_LMLO.png
# Kept 25739_RCC.png as is (positive)
# Kept 25739_RMLO.png as is (positive)
# Inverted 25809_LCC.png
# Inverted 25809_LMLO.png
# Inverted 25835_RCC.png
# Inverted 25835_RMLO.png
# Inverted 25842_LCC.png
# Inverted 25842_LMLO.png
# Inverted 25845_LCC.png
# Inverted 25845_LMLO.png
# Inverted 25985_RCC.png
# Inverted 25985_RMLO.png
# Inverted 25992_RCC.png
# Inverted 25992_RMLO.png
# Inverted 26110_RCC.png
# Inverted 26110_RMLO.png
# Kept 26173_LCC.png as is (positive)
# Kept 26173_LMLO.png as is (positive)
# Kept 26235_RCC.png as is (positive)
# Kept 26235_RMLO.png as is (positive)
# Kept 26510_RCC.png as is (positive)
# Kept 26510_RMLO.png as is (positive)
# Inverted 26563_LCC.png
# Inverted 26563_LMLO.png
# Inverted 26739_LCC.png
# Inverted 26739_LMLO.png
# Inverted 26769_RCC.png
# Inverted 26769_RMLO.png
# Inverted 26821_RCC.png
# Inverted 26821_RMLO.png
# Inverted 26890_LCC.png
# Inverted 26890_LMLO.png
# Inverted 26908_RCC.png
# Inverted 26908_RMLO.png
# Inverted 26957_LCC.png
# Inverted 26957_LMLO.png
# Inverted 27028_RCC.png
# Inverted 27028_RMLO.png
# Kept 27074_LCC.png as is (positive)
# Kept 27074_LMLO.png as is (positive)
# Kept 27184_RCC.png as is (positive)
# Kept 27184_RMLO.png as is (positive)
# Kept 27337_LCC.png as is (positive)
# Kept 27337_LMLO.png as is (positive)
# Inverted 27360_LCC.png
# Inverted 27360_LMLO.png
# Inverted 27382_LCC.png
# Inverted 27382_LMLO.png
# Kept 27497_LCC.png as is (positive)
# Kept 27497_LMLO.png as is (positive)
# Inverted 27514_LCC.png
# Inverted 27514_LMLO.png
# Inverted 27517_RCC.png
# Inverted 27517_RMLO.png
# Inverted 27948_RCC.png
# Inverted 27948_RMLO.png
# Inverted 28006_LCC.png
# Inverted 28006_LMLO.png
# Inverted 28102_LCC.png
# Inverted 28102_LMLO.png
# Inverted 28215_RCC.png
# Inverted 28215_RMLO.png
# Inverted 28366_LCC.png
# Inverted 28366_LMLO.png
# Inverted 28413_LCC.png
# Inverted 28413_LMLO.png
# Inverted 28921_LCC.png
# Inverted 28921_LMLO.png
# Inverted 29007_LCC.png
# Inverted 29007_LMLO.png
# Inverted 29032_LCC.png
# Inverted 29032_LMLO.png
# Inverted 29061_RCC.png
# Inverted 29061_RMLO.png
# Inverted 29314_LCC.png
# Inverted 29314_LMLO.png
# Inverted 29541_LCC.png
# Inverted 29541_LMLO.png
# Inverted 29597_RCC.png
# Inverted 29597_RMLO.png
# Kept 30086_RCC.png as is (positive)
# Kept 30086_RMLO.png as is (positive)
# Inverted 30147_LCC.png
# Inverted 30147_LMLO.png
# Inverted 30243_RCC.png
# Inverted 30243_RMLO.png
# Inverted 30304_LCC.png
# Inverted 30304_LMLO.png
# Inverted 30461_RCC.png
# Inverted 30461_RMLO.png
# Kept 30517_LCC.png as is (positive)
# Kept 30517_LMLO.png as is (positive)
# Inverted 30640_LCC.png
# Inverted 30640_LMLO.png
# Inverted 30671_RCC.png
# Inverted 30671_RMLO.png
# Inverted 30743_LCC.png
# Inverted 30743_LMLO.png
# Kept 30830_RCC.png as is (positive)
# Kept 30830_RMLO.png as is (positive)
# Inverted 30966_RCC.png
# Inverted 30966_RMLO.png
# Inverted 31110_LCC.png
# Inverted 31110_LMLO.png
# Inverted 31125_RCC.png
# Inverted 31125_RMLO.png
# Inverted 31175_RCC.png
# Inverted 31175_RMLO.png
# Inverted 31183_RCC.png
# Inverted 31183_RMLO.png
# Inverted 31226_RCC.png
# Inverted 31226_RMLO.png
# Inverted 31235_LCC.png
# Inverted 31235_LMLO.png
# Kept 31247_LCC.png as is (positive)
# Kept 31247_LMLO.png as is (positive)
# Inverted 31295_LCC.png
# Inverted 31295_LMLO.png
# Kept 31633_RCC.png as is (positive)
# Kept 31633_RMLO.png as is (positive)
# Inverted 31642_RCC.png
# Inverted 31642_RMLO.png
# Inverted 31679_RCC.png
# Inverted 31679_RMLO.png
# Inverted 31753_RCC.png
# Inverted 31753_RMLO.png
# Kept 31862_LCC.png as is (positive)
# Kept 31862_LMLO.png as is (positive)
# Inverted 32322_LCC.png
# Inverted 32322_LMLO.png
# Inverted 32518_LCC.png
# Inverted 32518_LMLO.png
# Kept 32665_LCC.png as is (positive)
# Kept 32665_LMLO.png as is (positive)
# Kept 32871_RCC.png as is (positive)
# Kept 32871_RMLO.png as is (positive)
# Inverted 32893_RCC.png
# Inverted 32893_RMLO.png
# Inverted 32928_RCC.png
# Inverted 32928_RMLO.png
# Inverted 33053_RCC.png
# Inverted 33053_RMLO.png
# Kept 33200_RCC.png as is (positive)
# Kept 33200_RMLO.png as is (positive)
# Inverted 33420_LCC.png
# Inverted 33420_LMLO.png
# Inverted 33514_LCC.png
# Inverted 33514_LMLO.png
# Inverted 33537_RCC.png
# Inverted 33537_RMLO.png
# Kept 33710_RCC.png as is (positive)
# Kept 33710_RMLO.png as is (positive)
# Inverted 33816_RCC.png
# Inverted 33816_RMLO.png
# Inverted 33903_LCC.png
# Inverted 33903_LMLO.png
# Kept 33977_RCC.png as is (positive)
# Kept 33977_RMLO.png as is (positive)
# Inverted 34059_LCC.png
# Inverted 34059_LMLO.png
# Inverted 34212_RCC.png
# Inverted 34212_RMLO.png
# Inverted 34264_RCC.png
# Inverted 34264_RMLO.png
# Inverted 34289_LCC.png
# Inverted 34289_LMLO.png
# Inverted 34332_LCC.png
# Inverted 34332_LMLO.png
# Inverted 34525_LCC.png
# Inverted 34525_LMLO.png
# Inverted 34548_RCC.png
# Inverted 34548_RMLO.png
# Inverted 34594_LCC.png
# Inverted 34594_LMLO.png
# Inverted 34614_RCC.png
# Inverted 34614_RMLO.png
# Kept 34639_RCC.png as is (positive)
# Kept 34639_RMLO.png as is (positive)
# Inverted 34719_LCC.png
# Inverted 34719_LMLO.png
# Inverted 35058_RCC.png
# Inverted 35058_RMLO.png
# Inverted 35084_RCC.png
# Inverted 35084_RMLO.png
# Inverted 35106_LCC.png
# Inverted 35106_LMLO.png
# Inverted 35146_LCC.png
# Inverted 35146_LMLO.png
# Inverted 35163_RCC.png
# Inverted 35163_RMLO.png
# Inverted 35177_LCC.png
# Kept 35177_LMLO.png as is (positive)
# Kept 35371_RCC.png as is (positive)
# Kept 35371_RMLO.png as is (positive)
# Kept 35435_RCC.png as is (positive)
# Kept 35435_RMLO.png as is (positive)
# Kept 35535_RCC.png as is (positive)
# Kept 35535_RMLO.png as is (positive)
# Inverted 35578_RCC.png
# Inverted 35578_RMLO.png
# Inverted 35639_LCC.png
# Inverted 35639_LMLO.png
# Inverted 35643_LCC.png
# Inverted 35643_LMLO.png
# Inverted 35743_RCC.png
# Inverted 35743_RMLO.png
# Kept 35880_RCC.png as is (positive)
# Kept 35880_RMLO.png as is (positive)
# Inverted 35969_LCC.png
# Inverted 35969_LMLO.png
# Inverted 36001_LCC.png
# Inverted 36001_LMLO.png
# Inverted 36046_RCC.png
# Inverted 36046_RMLO.png
# Inverted 36161_RCC.png
# Inverted 36161_RMLO.png
# Kept 36206_LCC.png as is (positive)
# Kept 36206_LMLO.png as is (positive)
# Kept 36213_LCC.png as is (positive)
# Kept 36213_LMLO.png as is (positive)
# Kept 36248_LCC.png as is (positive)
# Kept 36248_LMLO.png as is (positive)
# Inverted 36364_RCC.png
# Inverted 36364_RMLO.png
# Inverted 36512_RCC.png
# Inverted 36512_RMLO.png
# Inverted 36664_RCC.png
# Inverted 36664_RMLO.png
# Inverted 36701_LCC.png
# Inverted 36701_LMLO.png
# Inverted 36747_RCC.png
# Inverted 36747_RMLO.png
# Inverted 36774_RCC.png
# Inverted 36774_RMLO.png
# Inverted 36792_LCC.png
# Inverted 36792_LMLO.png
# Inverted 36964_RCC.png
# Inverted 36964_RMLO.png
# Inverted 37015_LCC.png
# Inverted 37015_LMLO.png
# Inverted 37185_LCC.png
# Inverted 37185_LMLO.png
# Inverted 37355_RCC.png
# Inverted 37355_RMLO.png
# Inverted 37647_LCC.png
# Inverted 37647_LMLO.png
# Inverted 37687_LCC.png
# Inverted 37687_LMLO.png
# Inverted 37692_LCC.png
# Inverted 37692_LMLO.png
# Inverted 37714_RCC.png
# Inverted 37714_RMLO.png
# Kept 37832_RCC.png as is (positive)
# Kept 37832_RMLO.png as is (positive)
# Inverted 37881_RCC.png
# Inverted 37881_RMLO.png
# Inverted 37892_LCC.png
# Inverted 37892_LMLO.png
# Inverted 37994_RCC.png
# Inverted 37994_RMLO.png
# Inverted 38038_LCC.png
# Inverted 38038_LMLO.png
# Inverted 38074_LCC.png
# Inverted 38074_LMLO.png
# Kept 38361_RCC.png as is (positive)
# Kept 38361_RMLO.png as is (positive)
# Inverted 38455_LCC.png
# Inverted 38455_LMLO.png
# Inverted 38487_RCC.png
# Inverted 38487_RMLO.png
# Inverted 38501_LCC.png
# Inverted 38501_LMLO.png
# Kept 38545_LCC.png as is (positive)
# Kept 38545_LMLO.png as is (positive)
# Inverted 38667_LCC.png
# Inverted 38667_LMLO.png
# Inverted 38874_RCC.png
# Inverted 38874_RMLO.png
# Inverted 38914_LCC.png
# Inverted 38914_LMLO.png
# Inverted 39048_LCC.png
# Inverted 39048_LMLO.png
# Inverted 39061_LCC.png
# Inverted 39061_LMLO.png
# Inverted 39229_LCC.png
# Inverted 39229_LMLO.png
# Kept 39288_RCC.png as is (positive)
# Kept 39288_RMLO.png as is (positive)
# Inverted 39324_RCC.png
# Inverted 39324_RMLO.png
# Inverted 39434_RCC.png
# Inverted 39434_RMLO.png
# Kept 39513_LCC.png as is (positive)
# Kept 39513_LMLO.png as is (positive)
# Inverted 39617_LCC.png
# Inverted 39617_LMLO.png
# Kept 39624_LCC.png as is (positive)
# Kept 39624_LMLO.png as is (positive)
# Inverted 39995_LCC.png
# Inverted 39995_LMLO.png
# Kept 40063_RCC.png as is (positive)
# Kept 40063_RMLO.png as is (positive)
# Kept 40158_LCC.png as is (positive)
# Kept 40158_LMLO.png as is (positive)
# Inverted 40229_LCC.png
# Inverted 40229_LMLO.png
# Kept 40253_LCC.png as is (positive)
# Kept 40253_LMLO.png as is (positive)
# Inverted 40258_LCC.png
# Inverted 40258_LMLO.png
# Inverted 40263_LCC.png
# Inverted 40263_LMLO.png
# Inverted 40350_LCC.png
# Inverted 40350_LMLO.png
# Inverted 40359_RCC.png
# Inverted 40359_RMLO.png
# Inverted 40495_RCC.png
# Inverted 40495_RMLO.png
# Inverted 40502_RCC.png
# Inverted 40502_RMLO.png
# Inverted 40684_RCC.png
# Inverted 40684_RMLO.png
# Inverted 40827_RCC.png
# Inverted 40827_RMLO.png
# Kept 40879_LCC.png as is (positive)
# Kept 40879_LMLO.png as is (positive)
# Kept 40897_RCC.png as is (positive)
# Kept 40897_RMLO.png as is (positive)
# Kept 41048_LCC.png as is (positive)
# Kept 41048_LMLO.png as is (positive)
# Inverted 41094_LCC.png
# Inverted 41094_LMLO.png
# Inverted 41125_RCC.png
# Inverted 41125_RMLO.png
# Kept 41204_LCC.png as is (positive)
# Kept 41204_LMLO.png as is (positive)
# Inverted 41237_LCC.png
# Inverted 41237_LMLO.png
# Kept 41271_LCC.png as is (positive)
# Kept 41271_LMLO.png as is (positive)
# Inverted 41354_LCC.png
# Inverted 41354_LMLO.png
# Kept 41461_RCC.png as is (positive)
# Kept 41461_RMLO.png as is (positive)
# Inverted 41522_RCC.png
# Inverted 41522_RMLO.png
# Inverted 41647_LCC.png
# Inverted 41647_LMLO.png
# Inverted 41787_LCC.png
# Inverted 41787_LMLO.png
# Kept 41793_LCC.png as is (positive)
# Kept 41793_LMLO.png as is (positive)
# Inverted 41851_RCC.png
# Inverted 41851_RMLO.png
# Kept 42162_RCC.png as is (positive)
# Kept 42162_RMLO.png as is (positive)
# Inverted 42178_RCC.png
# Inverted 42178_RMLO.png
# Inverted 42300_LCC.png
# Inverted 42300_LMLO.png
# Inverted 42347_RCC.png
# Inverted 42347_RMLO.png
# Kept 42429_RCC.png as is (positive)
# Kept 42429_RMLO.png as is (positive)
# Inverted 42490_RCC.png
# Inverted 42490_RMLO.png
# Kept 42700_LCC.png as is (positive)
# Kept 42700_LMLO.png as is (positive)
# Inverted 42768_RCC.png
# Inverted 42768_RMLO.png
# Kept 42803_LCC.png as is (positive)
# Kept 42803_LMLO.png as is (positive)
# Inverted 42828_RCC.png
# Inverted 42828_RMLO.png
# Inverted 42853_RCC.png
# Inverted 42853_RMLO.png
# Inverted 42880_LCC.png
# Inverted 42880_LMLO.png
# Kept 42928_LCC.png as is (positive)
# Kept 42928_LMLO.png as is (positive)
# Kept 42992_LCC.png as is (positive)
# Kept 42992_LMLO.png as is (positive)
# Inverted 43254_LCC.png
# Inverted 43254_LMLO.png
# Inverted 43287_LCC.png
# Inverted 43287_LMLO.png
# Kept 43350_LCC.png as is (positive)
# Kept 43350_LMLO.png as is (positive)
# Kept 43361_LCC.png as is (positive)
# Kept 43361_LMLO.png as is (positive)
# Inverted 43402_RCC.png
# Inverted 43402_RMLO.png
# Inverted 43457_RCC.png
# Inverted 43457_RMLO.png
# Inverted 43503_LCC.png
# Inverted 43503_LMLO.png
# Inverted 43524_RCC.png
# Inverted 43524_RMLO.png
# Inverted 43995_RCC.png
# Inverted 43995_RMLO.png
# Inverted 44052_RCC.png
# Inverted 44052_RMLO.png
# Inverted 44177_RCC.png
# Inverted 44177_RMLO.png
# Inverted 44391_RCC.png
# Inverted 44391_RMLO.png
# Inverted 44442_RCC.png
# Inverted 44442_RMLO.png
# Kept 44503_RCC.png as is (positive)
# Kept 44503_RMLO.png as is (positive)
# Inverted 44894_RCC.png
# Inverted 44894_RMLO.png
# Inverted 45518_RCC.png
# Inverted 45518_RMLO.png
# Inverted 45646_LCC.png
# Inverted 45646_LMLO.png
# Inverted 45670_LCC.png
# Inverted 45670_LMLO.png
# Kept 45713_RCC.png as is (positive)
# Kept 45713_RMLO.png as is (positive)
# Inverted 45786_RCC.png
# Inverted 45786_RMLO.png
# Inverted 45906_RCC.png
# Inverted 45906_RMLO.png
# Inverted 45986_RCC.png
# Inverted 45986_RMLO.png
# Inverted 46232_LCC.png
# Inverted 46232_LMLO.png
# Inverted 46391_LCC.png
# Inverted 46391_LMLO.png
# Inverted 46393_LCC.png
# Inverted 46393_LMLO.png
# Inverted 46478_RCC.png
# Inverted 46478_RMLO.png
# Inverted 46574_LCC.png
# Inverted 46574_LMLO.png
# Inverted 46674_LCC.png
# Inverted 46674_LMLO.png
# Inverted 46693_RCC.png
# Inverted 46693_RMLO.png
# Inverted 46712_LCC.png
# Inverted 46712_LMLO.png
# Inverted 46819_RCC.png
# Inverted 46819_RMLO.png
# Inverted 46837_RCC.png
# Inverted 46837_RMLO.png
# Inverted 46935_RCC.png
# Inverted 46935_RMLO.png
# Inverted 46971_LCC.png
# Inverted 46971_LMLO.png
# Inverted 47016_LCC.png
# Inverted 47016_LMLO.png
# Inverted 47041_LCC.png
# Inverted 47041_LMLO.png
# Inverted 47200_RCC.png
# Inverted 47200_RMLO.png
# Inverted 47241_RCC.png
# Inverted 47241_RMLO.png
# Kept 47265_RCC.png as is (positive)
# Kept 47265_RMLO.png as is (positive)
# Inverted 47304_LCC.png
# Inverted 47304_LMLO.png
# Inverted 47328_LCC.png
# Inverted 47328_LMLO.png
# Inverted 47687_RCC.png
# Inverted 47687_RMLO.png
# Kept 47989_LCC.png as is (positive)
# Kept 47989_LMLO.png as is (positive)
# Inverted 48113_RCC.png
# Inverted 48113_RMLO.png
# Inverted 48479_RCC.png
# Inverted 48479_RMLO.png
# Inverted 48535_LCC.png
# Inverted 48535_LMLO.png
# Inverted 48737_LCC.png
# Inverted 48737_LMLO.png
# Inverted 48745_RCC.png
# Inverted 48745_RMLO.png
# Inverted 48790_LCC.png
# Inverted 48790_LMLO.png
# Inverted 48893_LCC.png
# Inverted 48893_LMLO.png
# Inverted 49199_LCC.png
# Inverted 49199_LMLO.png
# Kept 49496_LCC.png as is (positive)
# Kept 49496_LMLO.png as is (positive)
# Inverted 49504_LCC.png
# Inverted 49504_LMLO.png
# Inverted 49903_RCC.png
# Inverted 49903_RMLO.png
# Inverted 50172_LCC.png
# Inverted 50172_LMLO.png
# Inverted 50264_RCC.png
# Inverted 50264_RMLO.png
# Inverted 50303_LCC.png
# Inverted 50303_LMLO.png
# Inverted 50383_RCC.png
# Inverted 50383_RMLO.png
# Inverted 50485_RCC.png
# Inverted 50485_RMLO.png
# Inverted 50509_LCC.png
# Inverted 50509_LMLO.png
# Inverted 50510_RCC.png
# Inverted 50510_RMLO.png
# Inverted 50991_LCC.png
# Inverted 50991_LMLO.png
# Kept 51041_LCC.png as is (positive)
# Kept 51041_LMLO.png as is (positive)
# Inverted 51096_LCC.png
# Inverted 51096_LMLO.png
# Inverted 51106_RCC.png
# Inverted 51106_RMLO.png
# Inverted 51121_RCC.png
# Inverted 51121_RMLO.png
# Kept 51128_RCC.png as is (positive)
# Kept 51128_RMLO.png as is (positive)
# Kept 51195_LCC.png as is (positive)
# Kept 51195_LMLO.png as is (positive)
# Inverted 51243_LCC.png
# Inverted 51243_LMLO.png
# Inverted 51382_LCC.png
# Inverted 51382_LMLO.png
# Inverted 51480_LCC.png
# Inverted 51480_LMLO.png
# Inverted 51710_RCC.png
# Inverted 51710_RMLO.png
# Inverted 51845_LCC.png
# Inverted 51845_LMLO.png
# Inverted 52159_LCC.png
# Inverted 52159_LMLO.png
# Inverted 52215_LCC.png
# Inverted 52215_LMLO.png
# Inverted 52318_LCC.png
# Inverted 52318_LMLO.png
# Inverted 52676_RCC.png
# Inverted 52676_RMLO.png
# Inverted 52814_RCC.png
# Inverted 52814_RMLO.png
# Inverted 52880_LCC.png
# Inverted 52880_LMLO.png
# Inverted 53421_RCC.png
# Inverted 53421_RMLO.png
# Kept 53503_LCC.png as is (positive)
# Kept 53503_LMLO.png as is (positive)
# Inverted 53543_RCC.png
# Inverted 53543_RMLO.png
# Inverted 53569_RCC.png
# Inverted 53569_RMLO.png
# Kept 53582_LCC.png as is (positive)
# Kept 53582_LMLO.png as is (positive)
# Kept 53589_LCC.png as is (positive)
# Kept 53589_LMLO.png as is (positive)
# Kept 53796_LCC.png as is (positive)
# Kept 53796_LMLO.png as is (positive)
# Inverted 53799_RCC.png
# Inverted 53799_RMLO.png
# Inverted 53848_LCC.png
# Inverted 53848_LMLO.png
# Kept 53906_RCC.png as is (positive)
# Kept 53906_RMLO.png as is (positive)
# Inverted 54036_LCC.png
# Inverted 54036_LMLO.png
# Kept 54543_RCC.png as is (positive)
# Kept 54543_RMLO.png as is (positive)
# Inverted 54601_LCC.png
# Inverted 54601_LMLO.png
# Inverted 54603_LCC.png
# Inverted 54603_LMLO.png
# Inverted 54856_LCC.png
# Inverted 54856_LMLO.png
# Inverted 55146_LCC.png
# Inverted 55146_LMLO.png
# Kept 55186_LCC.png as is (positive)
# Kept 55186_LMLO.png as is (positive)
# Kept 55212_RCC.png as is (positive)
# Kept 55212_RMLO.png as is (positive)
# Inverted 55354_RCC.png
# Inverted 55354_RMLO.png
# Inverted 55396_LCC.png
# Inverted 55396_LMLO.png
# Inverted 55571_LCC.png
# Inverted 55571_LMLO.png
# Inverted 55589_LCC.png
# Inverted 55589_LMLO.png
# Inverted 55853_LCC.png
# Inverted 55853_LMLO.png
# Inverted 55889_RCC.png
# Inverted 55889_RMLO.png
# Inverted 56015_LCC.png
# Inverted 56015_LMLO.png
# Inverted 56072_LCC.png
# Inverted 56072_LMLO.png
# Inverted 56080_RCC.png
# Inverted 56080_RMLO.png
# Kept 56153_RCC.png as is (positive)
# Kept 56153_RMLO.png as is (positive)
# Kept 56190_LCC.png as is (positive)
# Kept 56190_LMLO.png as is (positive)
# Kept 56195_RCC.png as is (positive)
# Kept 56195_RMLO.png as is (positive)
# Inverted 56218_RCC.png
# Inverted 56218_RMLO.png
# Inverted 56251_RCC.png
# Inverted 56251_RMLO.png
# Inverted 56374_LCC.png
# Inverted 56374_LMLO.png
# Inverted 56440_LCC.png
# Inverted 56440_LMLO.png
# Inverted 56457_LCC.png
# Inverted 56457_LMLO.png
# Kept 56520_LCC.png as is (positive)
# Kept 56520_LMLO.png as is (positive)
# Kept 56552_RCC.png as is (positive)
# Kept 56552_RMLO.png as is (positive)
# Inverted 56634_RCC.png
# Inverted 56634_RMLO.png
# Inverted 56722_RCC.png
# Inverted 56722_RMLO.png
# Inverted 56877_LCC.png
# Inverted 56877_LMLO.png
# Inverted 56905_LCC.png
# Inverted 56905_LMLO.png
# Inverted 56914_LCC.png
# Inverted 56914_LMLO.png
# Inverted 57059_LCC.png
# Inverted 57059_LMLO.png
# Inverted 57135_RCC.png
# Inverted 57135_RMLO.png
# Inverted 57246_RCC.png
# Inverted 57246_RMLO.png
# Inverted 57439_LCC.png
# Inverted 57439_LMLO.png
# Kept 57577_LCC.png as is (positive)
# Kept 57577_LMLO.png as is (positive)
# Kept 57794_RCC.png as is (positive)
# Kept 57794_RMLO.png as is (positive)
# Kept 57856_RCC.png as is (positive)
# Kept 57856_RMLO.png as is (positive)
# Kept 58102_LCC.png as is (positive)
# Kept 58102_LMLO.png as is (positive)
# Kept 58197_LCC.png as is (positive)
# Kept 58197_LMLO.png as is (positive)
# Inverted 58282_RCC.png
# Inverted 58282_RMLO.png
# Kept 58304_RCC.png as is (positive)
# Kept 58304_RMLO.png as is (positive)
# Inverted 58322_LCC.png
# Inverted 58322_LMLO.png
# Inverted 58525_LCC.png
# Inverted 58525_LMLO.png
# Kept 58551_RCC.png as is (positive)
# Kept 58551_RMLO.png as is (positive)
# Inverted 58607_LCC.png
# Inverted 58607_LMLO.png
# Inverted 58682_LCC.png
# Inverted 58682_LMLO.png
# Inverted 58922_RCC.png
# Inverted 58922_RMLO.png
# Inverted 59067_RCC.png
# Inverted 59067_RMLO.png
# Inverted 59128_RCC.png
# Inverted 59128_RMLO.png
# Inverted 59143_RCC.png
# Inverted 59143_RMLO.png
# Inverted 59255_RCC.png
# Inverted 59255_RMLO.png
# Inverted 59375_RCC.png
# Inverted 59375_RMLO.png
# Inverted 59396_RCC.png
# Inverted 59396_RMLO.png
# Inverted 59523_RCC.png
# Inverted 59523_RMLO.png
# Inverted 59627_LCC.png
# Inverted 59627_LMLO.png
# Inverted 59721_LCC.png
# Inverted 59721_LMLO.png
# Inverted 59722_RCC.png
# Inverted 59722_RMLO.png
# Kept 59824_LCC.png as is (positive)
# Kept 59824_LMLO.png as is (positive)
# Kept 59890_LCC.png as is (positive)
# Kept 59890_LMLO.png as is (positive)
# Inverted 60009_LCC.png
# Inverted 60009_LMLO.png
# Inverted 60158_LCC.png
# Inverted 60158_LMLO.png
# Inverted 60185_RCC.png
# Inverted 60185_RMLO.png
# Inverted 60241_RCC.png
# Inverted 60241_RMLO.png
# Kept 60287_LCC.png as is (positive)
# Kept 60287_LMLO.png as is (positive)
# Inverted 60555_RCC.png
# Inverted 60555_RMLO.png
# Inverted 60777_RCC.png
# Inverted 60777_RMLO.png
# Inverted 60895_LCC.png
# Inverted 60895_LMLO.png
# Inverted 60947_LCC.png
# Inverted 60947_LMLO.png
# Inverted 60967_RCC.png
# Inverted 60967_RMLO.png
# Inverted 61008_RCC.png
# Inverted 61008_RMLO.png
# Inverted 61314_LCC.png
# Inverted 61314_LMLO.png
# Kept 61491_RCC.png as is (positive)
# Kept 61491_RMLO.png as is (positive)
# Inverted 61513_LCC.png
# Inverted 61513_LMLO.png
# Inverted 61634_RCC.png
# Inverted 61634_RMLO.png
# Inverted 61965_LCC.png
# Inverted 61965_LMLO.png
# Kept 61986_RCC.png as is (positive)
# Kept 61986_RMLO.png as is (positive)
# Inverted 62349_LCC.png
# Inverted 62349_LMLO.png
# Inverted 62408_LCC.png
# Inverted 62408_LMLO.png
# Inverted 62442_RCC.png
# Inverted 62442_RMLO.png
# Inverted 62534_RCC.png
# Inverted 62534_RMLO.png
# Inverted 62662_RCC.png
# Inverted 62662_RMLO.png
# Inverted 62722_LCC.png
# Inverted 62722_LMLO.png
# Inverted 62854_RCC.png
# Inverted 62854_RMLO.png
# Inverted 62910_LCC.png
# Inverted 62910_LMLO.png
# Inverted 63014_LCC.png
# Inverted 63014_LMLO.png
# Kept 63046_LCC.png as is (positive)
# Kept 63046_LMLO.png as is (positive)
# Inverted 63093_RCC.png
# Inverted 63093_RMLO.png
# Inverted 63285_RCC.png
# Inverted 63285_RMLO.png
# Inverted 63473_LCC.png
# Inverted 63473_LMLO.png
# Inverted 63498_RCC.png
# Inverted 63498_RMLO.png
# Kept 63529_RCC.png as is (positive)
# Kept 63529_RMLO.png as is (positive)
# Inverted 63659_RCC.png
# Inverted 63659_RMLO.png
# Inverted 63811_RCC.png
# Inverted 63811_RMLO.png
# Inverted 63836_RCC.png
# Inverted 63836_RMLO.png
# Inverted 63864_LCC.png
# Inverted 63864_LMLO.png
# Kept 64040_RCC.png as is (positive)
# Kept 64040_RMLO.png as is (positive)
# Inverted 64199_RCC.png
# Inverted 64199_RMLO.png
# Kept 64203_LCC.png as is (positive)
# Kept 64203_LMLO.png as is (positive)
# Inverted 64261_LCC.png
# Inverted 64261_LMLO.png
# Inverted 64391_LCC.png
# Inverted 64391_LMLO.png
# Inverted 64628_LCC.png
# Inverted 64628_LMLO.png
# Inverted 64828_LCC.png
# Inverted 64828_LMLO.png
# Inverted 64838_RCC.png
# Inverted 64838_RMLO.png
# Inverted 64995_RCC.png
# Inverted 64995_RMLO.png
# Kept 65281_LCC.png as is (positive)
# Kept 65281_LMLO.png as is (positive)
# Inverted 65409_RCC.png
# Inverted 65409_RMLO.png
# Inverted 65598_RCC.png
# Inverted 65598_RMLO.png
# Kept 65861_RCC.png as is (positive)
# Kept 65861_RMLO.png as is (positive)
# Inverted 65907_LCC.png
# Inverted 65907_LMLO.png
# Kept 65930_LCC.png as is (positive)
# Kept 65930_LMLO.png as is (positive)
# Inverted 65978_RCC.png
# Inverted 65978_RMLO.png
# Inverted 66010_RCC.png
# Inverted 66010_RMLO.png
# Inverted 66080_LCC.png
# Inverted 66080_LMLO.png
# Inverted 66341_RCC.png
# Inverted 66341_RMLO.png
# Kept 66650_LCC.png as is (positive)
# Kept 66650_LMLO.png as is (positive)
# Kept 66676_LCC.png as is (positive)
# Kept 66676_LMLO.png as is (positive)
# Inverted 66783_RCC.png
# Inverted 66783_RMLO.png
# Inverted 66888_LCC.png
# Inverted 66888_LMLO.png
# Inverted 67204_LCC.png
# Inverted 67204_LMLO.png
# Kept 67222_RCC.png as is (positive)
# Kept 67222_RMLO.png as is (positive)
# Kept 67399_RCC.png as is (positive)
# Kept 67399_RMLO.png as is (positive)
# Kept 67403_LCC.png as is (positive)
# Kept 67403_LMLO.png as is (positive)
# Inverted 67736_LCC.png
# Inverted 67736_LMLO.png
# Inverted 67813_RCC.png
# Inverted 67813_RMLO.png
# Inverted 67889_RCC.png
# Inverted 67889_RMLO.png
# Inverted 68014_RCC.png
# Inverted 68014_RMLO.png
# Kept 68522_RCC.png as is (positive)
# Kept 68522_RMLO.png as is (positive)
# Kept 68565_LCC.png as is (positive)
# Kept 68565_LMLO.png as is (positive)
# Inverted 68619_RCC.png
# Inverted 68619_RMLO.png
# Inverted 68654_LCC.png
# Inverted 68654_LMLO.png
# Inverted 68668_LCC.png
# Inverted 68668_LMLO.png
# Kept 68844_LCC.png as is (positive)
# Kept 68844_LMLO.png as is (positive)
# Inverted 68978_RCC.png
# Inverted 68978_RMLO.png
# Inverted 69013_LCC.png
# Inverted 69013_LMLO.png
# Inverted 69351_RCC.png
# Inverted 69351_RMLO.png
# Kept 69479_RCC.png as is (positive)
# Kept 69479_RMLO.png as is (positive)
# Kept 69519_RCC.png as is (positive)
# Kept 69519_RMLO.png as is (positive)
# Inverted 69587_RCC.png
# Inverted 69587_RMLO.png
# Inverted 69617_LCC.png
# Inverted 69617_LMLO.png
# Inverted 69714_LCC.png
# Inverted 69714_LMLO.png
# Inverted 69745_RCC.png
# Inverted 69745_RMLO.png
# Inverted 69957_LCC.png
# Inverted 69957_LMLO.png
# Kept 69975_LCC.png as is (positive)
# Kept 69975_LMLO.png as is (positive)
# Inverted 70092_LCC.png
# Inverted 70092_LMLO.png
# Inverted 70227_LCC.png
# Inverted 70227_LMLO.png
# Kept 70245_RCC.png as is (positive)
# Kept 70245_RMLO.png as is (positive)
# Inverted 70384_LCC.png
# Inverted 70384_LMLO.png
# Inverted 70727_RCC.png
# Inverted 70727_RMLO.png
# Inverted 70770_RCC.png
# Inverted 70770_RMLO.png
# Inverted 70798_LCC.png
# Inverted 70798_LMLO.png
# Inverted 70992_LCC.png
# Inverted 70992_LMLO.png
# Kept 71009_RCC.png as is (positive)
# Kept 71009_RMLO.png as is (positive)
# Inverted 71018_LCC.png
# Inverted 71018_LMLO.png
# Inverted 71019_LCC.png
# Inverted 71019_LMLO.png
# Inverted 71091_LCC.png
# Inverted 71091_LMLO.png
# Inverted 71220_LCC.png
# Inverted 71220_LMLO.png
# Inverted 71256_RCC.png
# Inverted 71256_RMLO.png
# Inverted 71317_RCC.png
# Inverted 71317_RMLO.png
# Inverted 71400_LCC.png
# Inverted 71400_LMLO.png
# Inverted 71437_LCC.png
# Inverted 71437_LMLO.png
# Kept 71454_LCC.png as is (positive)
# Kept 71454_LMLO.png as is (positive)
# Kept 71534_RCC.png as is (positive)
# Kept 71534_RMLO.png as is (positive)
# Inverted 71543_LCC.png
# Inverted 71543_LMLO.png
# Kept 72006_RCC.png as is (positive)
# Kept 72006_RMLO.png as is (positive)
# Inverted 72037_RCC.png
# Inverted 72037_RMLO.png
# Inverted 72194_LCC.png
# Inverted 72194_LMLO.png
# Kept 72262_LCC.png as is (positive)
# Kept 72262_LMLO.png as is (positive)
# Inverted 72331_RCC.png
# Inverted 72331_RMLO.png
# Inverted 72392_RCC.png
# Inverted 72392_RMLO.png
# Inverted 72421_LCC.png
# Inverted 72421_LMLO.png
# Inverted 72676_LCC.png
# Inverted 72676_LMLO.png
# Inverted 72813_RCC.png
# Inverted 72813_RMLO.png
# Kept 72947_LCC.png as is (positive)
# Kept 72947_LMLO.png as is (positive)
# Kept 73066_RCC.png as is (positive)
# Kept 73066_RMLO.png as is (positive)
# Kept 73112_LCC.png as is (positive)
# Kept 73112_LMLO.png as is (positive)
# Inverted 73300_RCC.png
# Inverted 73300_RMLO.png
# Kept 73433_RCC.png as is (positive)
# Kept 73433_RMLO.png as is (positive)
# Inverted 73435_LCC.png
# Inverted 73435_LMLO.png
# Inverted 73960_LCC.png
# Inverted 73960_LMLO.png
# Inverted 74115_RCC.png
# Inverted 74115_RMLO.png
# Inverted 74251_RCC.png
# Inverted 74251_RMLO.png
# Kept 74353_LCC.png as is (positive)
# Kept 74353_LMLO.png as is (positive)
# Inverted 74606_RCC.png
# Inverted 74606_RMLO.png
# Inverted 74622_RCC.png
# Inverted 74622_RMLO.png
# Kept 74703_RCC.png as is (positive)
# Kept 74703_RMLO.png as is (positive)
# Inverted 74737_LCC.png
# Inverted 74737_LMLO.png
# Inverted 74817_LCC.png
# Inverted 74817_LMLO.png
# Inverted 75062_LCC.png
# Inverted 75062_LMLO.png
# Inverted 75220_LCC.png
# Inverted 75220_LMLO.png
# Inverted 75246_RCC.png
# Inverted 75246_RMLO.png
# Kept 75266_RCC.png as is (positive)
# Kept 75266_RMLO.png as is (positive)
# Inverted 75289_LCC.png
# Inverted 75289_LMLO.png
# Inverted 75498_RCC.png
# Inverted 75498_RMLO.png
# Inverted 75598_LCC.png
# Inverted 75598_LMLO.png
# Inverted 75686_LCC.png
# Inverted 75686_LMLO.png
# Inverted 75718_RCC.png
# Inverted 75718_RMLO.png
# Inverted 75952_RCC.png
# Inverted 75952_RMLO.png
# Inverted 76052_LCC.png
# Inverted 76052_LMLO.png
# Inverted 76086_RCC.png
# Inverted 76086_RMLO.png
# Inverted 76182_RCC.png
# Inverted 76182_RMLO.png
# Inverted 76206_RCC.png
# Inverted 76206_RMLO.png
# Inverted 76344_LCC.png
# Inverted 76344_LMLO.png
# Inverted 76411_LCC.png
# Inverted 76411_LMLO.png
# Inverted 76437_LCC.png
# Inverted 76437_LMLO.png
# Inverted 76508_LCC.png
# Inverted 76508_LMLO.png
# Kept 76527_LCC.png as is (positive)
# Kept 76527_LMLO.png as is (positive)
# Inverted 76642_LCC.png
# Inverted 76642_LMLO.png
# Kept 76678_LCC.png as is (positive)
# Kept 76678_LMLO.png as is (positive)
# Kept 76682_LCC.png as is (positive)
# Kept 76682_LMLO.png as is (positive)
# Kept 76742_RCC.png as is (positive)
# Kept 76742_RMLO.png as is (positive)
# Inverted 76947_RCC.png
# Inverted 76947_RMLO.png
# Inverted 77037_RCC.png
# Inverted 77037_RMLO.png
# Inverted 77038_LCC.png
# Inverted 77038_LMLO.png
# Inverted 77173_RCC.png
# Inverted 77173_RMLO.png
# Inverted 77178_LCC.png
# Inverted 77178_LMLO.png
# Inverted 77467_LCC.png
# Inverted 77467_LMLO.png
# Kept 77511_LCC.png as is (positive)
# Kept 77511_LMLO.png as is (positive)
# Inverted 77593_RCC.png
# Inverted 77593_RMLO.png
# Inverted 77626_RCC.png
# Inverted 77626_RMLO.png
# Inverted 77676_LCC.png
# Inverted 77676_LMLO.png
# Inverted 77725_LCC.png
# Inverted 77725_LMLO.png
# Kept 77764_RCC.png as is (positive)
# Kept 77764_RMLO.png as is (positive)
# Inverted 77864_RCC.png
# Inverted 77864_RMLO.png
# Inverted 77897_LCC.png
# Inverted 77897_LMLO.png
# Inverted 77924_LCC.png
# Inverted 77924_LMLO.png
# Kept 77937_LCC.png as is (positive)
# Kept 77937_LMLO.png as is (positive)
# Inverted 78272_LCC.png
# Inverted 78272_LMLO.png
# Inverted 78309_RCC.png
# Inverted 78309_RMLO.png
# Inverted 78463_LCC.png
# Inverted 78463_LMLO.png
# Kept 78727_RCC.png as is (positive)
# Kept 78727_RMLO.png as is (positive)
# Kept 78743_LCC.png as is (positive)
# Kept 78743_LMLO.png as is (positive)
# Inverted 79065_LCC.png
# Inverted 79065_LMLO.png
# Kept 79100_LCC.png as is (positive)
# Kept 79100_LMLO.png as is (positive)
# Kept 79165_RCC.png as is (positive)
# Kept 79165_RMLO.png as is (positive)
# Inverted 79191_RCC.png
# Inverted 79191_RMLO.png
# Kept 79205_LCC.png as is (positive)
# Kept 79205_LMLO.png as is (positive)
# Inverted 79287_RCC.png
# Inverted 79287_RMLO.png
# Inverted 79380_LCC.png
# Inverted 79380_LMLO.png
# Inverted 79440_LCC.png
# Inverted 79440_LMLO.png
# Inverted 79448_RCC.png
# Inverted 79448_RMLO.png
# Kept 79483_LCC.png as is (positive)
# Kept 79483_LMLO.png as is (positive)
# Kept 79497_RCC.png as is (positive)
# Kept 79497_RMLO.png as is (positive)
# Kept 79719_LCC.png as is (positive)
# Kept 79719_LMLO.png as is (positive)
# Inverted 79780_LCC.png
# Inverted 79780_LMLO.png
# Inverted 79788_RCC.png
# Inverted 79788_RMLO.png
# Inverted 79950_RCC.png
# Inverted 79950_RMLO.png
# Kept 80041_RCC.png as is (positive)
# Kept 80041_RMLO.png as is (positive)
# Inverted 80080_LCC.png
# Inverted 80080_LMLO.png
# Inverted 80101_LCC.png
# Inverted 80101_LMLO.png
# Inverted 80224_RCC.png
# Inverted 80224_RMLO.png
# Kept 80316_RCC.png as is (positive)
# Kept 80316_RMLO.png as is (positive)
# Inverted 80349_RCC.png
# Inverted 80349_RMLO.png
# Kept 80425_LCC.png as is (positive)
# Kept 80425_LMLO.png as is (positive)
# Kept 80450_RCC.png as is (positive)
# Kept 80450_RMLO.png as is (positive)
# Inverted 80488_LCC.png
# Inverted 80488_LMLO.png
# Inverted 80542_LCC.png
# Inverted 80542_LMLO.png
# Inverted 80593_RCC.png
# Inverted 80593_RMLO.png
# Inverted 80714_RCC.png
# Inverted 80714_RMLO.png
# Inverted 80803_RCC.png
# Inverted 80803_RMLO.png
# Inverted 80994_RCC.png
# Inverted 80994_RMLO.png
# Inverted 81005_LCC.png
# Inverted 81005_LMLO.png
# Inverted 81035_LCC.png
# Inverted 81035_LMLO.png
# Kept 81141_LCC.png as is (positive)
# Kept 81141_LMLO.png as is (positive)
# Inverted 81259_RCC.png
# Inverted 81259_RMLO.png
# Inverted 81338_RCC.png
# Inverted 81338_RMLO.png
# Kept 81429_RCC.png as is (positive)
# Kept 81429_RMLO.png as is (positive)
# Kept 81648_LCC.png as is (positive)
# Kept 81648_LMLO.png as is (positive)
# Inverted 81683_LCC.png
# Inverted 81683_LMLO.png
# Inverted 81746_RCC.png
# Inverted 81746_RMLO.png
# Kept 81922_RCC.png as is (positive)
# Kept 81922_RMLO.png as is (positive)
# Inverted 82004_RCC.png
# Inverted 82004_RMLO.png
# Inverted 82015_LCC.png
# Inverted 82015_LMLO.png
# Inverted 82026_LCC.png
# Inverted 82026_LMLO.png
# Inverted 82048_RCC.png
# Inverted 82048_RMLO.png
# Inverted 82180_LCC.png
# Inverted 82180_LMLO.png
# Inverted 82222_RCC.png
# Inverted 82222_RMLO.png
# Inverted 82240_LCC.png
# Inverted 82240_LMLO.png
# Kept 82294_LCC.png as is (positive)
# Kept 82294_LMLO.png as is (positive)
# Kept 82336_RCC.png as is (positive)
# Kept 82336_RMLO.png as is (positive)
# Inverted 82345_RCC.png
# Inverted 82345_RMLO.png
# Inverted 82411_LCC.png
# Inverted 82411_LMLO.png
# Inverted 82432_RCC.png
# Inverted 82432_RMLO.png
# Inverted 82450_RCC.png
# Inverted 82450_RMLO.png
# Inverted 82583_LCC.png
# Inverted 82583_LMLO.png
# Inverted 82588_RCC.png
# Inverted 82588_RMLO.png
# Inverted 82751_LCC.png
# Inverted 82751_LMLO.png
# Inverted 82796_RCC.png
# Inverted 82796_RMLO.png
# Inverted 83135_LCC.png
# Inverted 83135_LMLO.png
# Inverted 83162_LCC.png
# Inverted 83162_LMLO.png
# Inverted 83172_RCC.png
# Inverted 83172_RMLO.png
# Kept 83204_RCC.png as is (positive)
# Kept 83204_RMLO.png as is (positive)
# Inverted 83315_RCC.png
# Inverted 83315_RMLO.png
# Kept 83521_LCC.png as is (positive)
# Kept 83521_LMLO.png as is (positive)
# Inverted 83703_RCC.png
# Inverted 83703_RMLO.png
# Inverted 83795_RCC.png
# Inverted 83795_RMLO.png
# Inverted 83825_LCC.png
# Inverted 83825_LMLO.png
# Inverted 83940_RCC.png
# Inverted 83940_RMLO.png
# Inverted 83974_LCC.png
# Inverted 83974_LMLO.png
# Kept 83997_RCC.png as is (positive)
# Kept 83997_RMLO.png as is (positive)
# Inverted 84075_LCC.png
# Inverted 84075_LMLO.png
# Inverted 84108_RCC.png
# Inverted 84108_RMLO.png
# Inverted 84311_LCC.png
# Inverted 84311_LMLO.png
# Inverted 84343_LCC.png
# Inverted 84343_LMLO.png
# Inverted 84374_RCC.png
# Inverted 84374_RMLO.png
# Kept 84422_LCC.png as is (positive)
# Kept 84422_LMLO.png as is (positive)
# Inverted 84573_LCC.png
# Inverted 84573_LMLO.png
# Inverted 84991_RCC.png
# Inverted 84991_RMLO.png
# Inverted 85067_RCC.png
# Inverted 85067_RMLO.png
# Inverted 85322_LCC.png
# Inverted 85322_LMLO.png
# Inverted 85378_RCC.png
# Inverted 85378_RMLO.png
# Inverted 85568_RCC.png
# Inverted 85568_RMLO.png
# Inverted 85616_LCC.png
# Inverted 85616_LMLO.png
# Kept 85639_RCC.png as is (positive)
# Kept 85639_RMLO.png as is (positive)
# Inverted 85671_RCC.png
# Inverted 85671_RMLO.png
# Inverted 85695_LCC.png
# Inverted 85695_LMLO.png
# Inverted 85712_RCC.png
# Inverted 85712_RMLO.png
# Inverted 85934_LCC.png
# Inverted 85934_LMLO.png
# Inverted 85973_RCC.png
# Inverted 85973_RMLO.png
# Inverted 86191_RCC.png
# Inverted 86191_RMLO.png
# Inverted 86223_RCC.png
# Inverted 86223_RMLO.png
# Inverted 86481_LCC.png
# Inverted 86481_LMLO.png
# Kept 86535_LCC.png as is (positive)
# Kept 86535_LMLO.png as is (positive)
# Kept 86669_LCC.png as is (positive)
# Kept 86669_LMLO.png as is (positive)
# Inverted 86672_RCC.png
# Inverted 86672_RMLO.png
# Kept 86686_RCC.png as is (positive)
# Kept 86686_RMLO.png as is (positive)
# Inverted 86743_LCC.png
# Inverted 86743_LMLO.png
# Inverted 86845_LCC.png
# Inverted 86845_LMLO.png
# Inverted 86847_RCC.png
# Inverted 86847_RMLO.png
# Inverted 86863_RCC.png
# Inverted 86863_RMLO.png
# Inverted 86988_LCC.png
# Inverted 86988_LMLO.png
# Inverted 87009_RCC.png
# Inverted 87009_RMLO.png
# Kept 87092_RCC.png as is (positive)
# Kept 87092_RMLO.png as is (positive)
# Inverted 87196_RCC.png
# Inverted 87196_RMLO.png
# Inverted 87326_RCC.png
# Inverted 87326_RMLO.png
# Inverted 87329_RCC.png
# Inverted 87329_RMLO.png
# Inverted 87352_LCC.png
# Inverted 87352_LMLO.png
# Inverted 87499_LCC.png
# Inverted 87499_LMLO.png
# Inverted 87509_LCC.png
# Inverted 87509_LMLO.png
# Inverted 87803_LCC.png
# Inverted 87803_LMLO.png
# Inverted 87843_LCC.png
# Inverted 87843_LMLO.png
# Kept 87966_RCC.png as is (positive)
# Kept 87966_RMLO.png as is (positive)
# Inverted 87970_RCC.png
# Inverted 87970_RMLO.png
# Inverted 88049_RCC.png
# Inverted 88049_RMLO.png
# Inverted 88180_RCC.png
# Inverted 88180_RMLO.png
# Inverted 88294_LCC.png
# Inverted 88294_LMLO.png
# Inverted 88343_RCC.png
# Inverted 88343_RMLO.png
# Inverted 88386_RCC.png
# Inverted 88386_RMLO.png
# Inverted 88742_RCC.png
# Inverted 88742_RMLO.png
# Inverted 88764_LCC.png
# Inverted 88764_LMLO.png
# Kept 88802_RCC.png as is (positive)
# Kept 88802_RMLO.png as is (positive)
# Inverted 88804_LCC.png
# Inverted 88804_LMLO.png
# Inverted 88812_LCC.png
# Inverted 88812_LMLO.png
# Inverted 88871_RCC.png
# Inverted 88871_RMLO.png
# Inverted 89067_LCC.png
# Inverted 89067_LMLO.png
# Kept 89169_RCC.png as is (positive)
# Kept 89169_RMLO.png as is (positive)
# Inverted 89171_RCC.png
# Inverted 89171_RMLO.png
# Inverted 89202_LCC.png
# Inverted 89202_LMLO.png
# Inverted 89255_LCC.png
# Inverted 89255_LMLO.png
# Inverted 89264_LCC.png
# Inverted 89264_LMLO.png
# Kept 89337_RCC.png as is (positive)
# Kept 89337_RMLO.png as is (positive)
# Inverted 89366_LCC.png
# Inverted 89366_LMLO.png
# Inverted 89520_RCC.png
# Inverted 89520_RMLO.png
# Inverted 89630_LCC.png
# Inverted 89630_LMLO.png
# Inverted 89687_RCC.png
# Inverted 89687_RMLO.png
# Kept 89702_LCC.png as is (positive)
# Kept 89702_LMLO.png as is (positive)
# Kept 89727_LCC.png as is (positive)
# Kept 89727_LMLO.png as is (positive)
# Inverted 89777_RCC.png
# Inverted 89777_RMLO.png
# Inverted 89979_LCC.png
# Inverted 89979_LMLO.png
# Inverted 90081_RCC.png
# Inverted 90081_RMLO.png
# Inverted 90114_RCC.png
# Inverted 90114_RMLO.png
# Kept 90173_LCC.png as is (positive)
# Kept 90173_LMLO.png as is (positive)
# Kept 90188_RCC.png as is (positive)
# Kept 90188_RMLO.png as is (positive)
# Inverted 90275_RCC.png
# Inverted 90275_RMLO.png
# Kept 90287_RCC.png as is (positive)
# Kept 90287_RMLO.png as is (positive)
# Inverted 90354_LCC.png
# Inverted 90354_LMLO.png
# Inverted 90386_RCC.png
# Inverted 90386_RMLO.png
# Inverted 90520_LCC.png
# Inverted 90520_LMLO.png
# Inverted 90525_LCC.png
# Inverted 90525_LMLO.png
# Inverted 90677_RCC.png
# Inverted 90677_RMLO.png
# Kept 90740_LCC.png as is (positive)
# Kept 90740_LMLO.png as is (positive)
# Inverted 90946_RCC.png
# Inverted 90946_RMLO.png
# Inverted 91089_RCC.png
# Inverted 91089_RMLO.png
# Inverted 91111_LCC.png
# Inverted 91111_LMLO.png
# Inverted 91222_LCC.png
# Inverted 91222_LMLO.png
# Inverted 91396_RCC.png
# Inverted 91396_RMLO.png
# Kept 91476_RCC.png as is (positive)
# Kept 91476_RMLO.png as is (positive)
# Kept 91570_RCC.png as is (positive)
# Kept 91570_RMLO.png as is (positive)
# Inverted 91807_RCC.png
# Inverted 91807_RMLO.png
# Inverted 91973_LCC.png
# Inverted 91973_LMLO.png
# Inverted 91994_LCC.png
# Inverted 91994_LMLO.png
# Inverted 92048_LCC.png
# Inverted 92048_LMLO.png
# Inverted 92080_RCC.png
# Inverted 92080_RMLO.png
# Inverted 92190_RCC.png
# Inverted 92190_RMLO.png
# Inverted 92200_RCC.png
# Inverted 92200_RMLO.png
# Inverted 92248_LCC.png
# Inverted 92248_LMLO.png
# Kept 92267_LCC.png as is (positive)
# Kept 92267_LMLO.png as is (positive)
# Inverted 92291_LCC.png
# Inverted 92291_LMLO.png
# Inverted 92506_LCC.png
# Inverted 92506_LMLO.png
# Kept 92587_RCC.png as is (positive)
# Kept 92587_RMLO.png as is (positive)
# Inverted 92611_LCC.png
# Inverted 92611_LMLO.png
# Inverted 92663_LCC.png
# Inverted 92663_LMLO.png
# Inverted 92692_LCC.png
# Inverted 92692_LMLO.png
# Inverted 92744_LCC.png
# Inverted 92744_LMLO.png
# Kept 92783_RCC.png as is (positive)
# Kept 92783_RMLO.png as is (positive)
# Inverted 93054_LCC.png
# Inverted 93054_LMLO.png
# Kept 93276_RCC.png as is (positive)
# Kept 93276_RMLO.png as is (positive)
# Inverted 93622_RCC.png
# Inverted 93622_RMLO.png
# Kept 93624_RCC.png as is (positive)
# Kept 93624_RMLO.png as is (positive)
# Inverted 93630_RCC.png
# Inverted 93630_RMLO.png
# Inverted 93673_LCC.png
# Inverted 93673_LMLO.png
# Inverted 93831_RCC.png
# Inverted 93831_RMLO.png
# Inverted 93977_RCC.png
# Inverted 93977_RMLO.png
# Inverted 94258_RCC.png
# Inverted 94258_RMLO.png
# Inverted 94317_RCC.png
# Inverted 94317_RMLO.png
# Inverted 94436_RCC.png
# Inverted 94436_RMLO.png
# Inverted 94609_LCC.png
# Inverted 94609_LMLO.png
# Kept 94651_RCC.png as is (positive)
# Kept 94651_RMLO.png as is (positive)
# Inverted 94721_LCC.png
# Inverted 94721_LMLO.png
# Inverted 94769_LCC.png
# Inverted 94769_LMLO.png
# Kept 94794_LCC.png as is (positive)
# Kept 94794_LMLO.png as is (positive)
# Inverted 94838_LCC.png
# Inverted 94838_LMLO.png
# Inverted 94858_RCC.png
# Inverted 94858_RMLO.png
# Inverted 95024_LCC.png
# Inverted 95024_LMLO.png
# Kept 95044_LCC.png as is (positive)
# Kept 95044_LMLO.png as is (positive)
# Inverted 95116_LCC.png
# Inverted 95116_LMLO.png
# Inverted 95187_LCC.png
# Inverted 95187_LMLO.png
# Inverted 95494_RCC.png
# Inverted 95494_RMLO.png
# Inverted 95509_LCC.png
# Inverted 95509_LMLO.png
# Inverted 95559_LCC.png
# Inverted 95559_LMLO.png
# Inverted 95642_LCC.png
# Inverted 95642_LMLO.png
# Kept 95648_RCC.png as is (positive)
# Kept 95648_RMLO.png as is (positive)
# Inverted 95856_RCC.png
# Inverted 95856_RMLO.png
# Kept 95887_RCC.png as is (positive)
# Kept 95887_RMLO.png as is (positive)
# Inverted 96305_LCC.png
# Inverted 96305_LMLO.png
# Inverted 96329_RCC.png
# Inverted 96329_RMLO.png
# Inverted 96498_RCC.png
# Inverted 96498_RMLO.png
# Kept 96941_RCC.png as is (positive)
# Kept 96941_RMLO.png as is (positive)
# Inverted 96958_LCC.png
# Inverted 96958_LMLO.png
# Inverted 96991_RCC.png
# Inverted 96991_RMLO.png
# Inverted 97185_LCC.png
# Inverted 97185_LMLO.png
# Kept 97320_RCC.png as is (positive)
# Kept 97320_RMLO.png as is (positive)
# Inverted 97601_LCC.png
# Inverted 97601_LMLO.png
# Inverted 97679_LCC.png
# Inverted 97679_LMLO.png
# Inverted 97806_RCC.png
# Inverted 97806_RMLO.png
# Inverted 97822_RCC.png
# Inverted 97822_RMLO.png
# Inverted 97825_RCC.png
# Inverted 97825_RMLO.png
# Inverted 98214_RCC.png
# Inverted 98214_RMLO.png
# Inverted 98392_RCC.png
# Inverted 98392_RMLO.png
# Kept 98860_LCC.png as is (positive)
# Inverted 98870_RCC.png
# Inverted 98870_RMLO.png
# Inverted 98955_LCC.png
# Inverted 98955_LMLO.png
# Kept 99110_RCC.png as is (positive)
# Kept 99110_RMLO.png as is (positive)
# Inverted 99115_LCC.png
# Inverted 99115_LMLO.png
# Inverted 99362_RCC.png
# Inverted 99362_RMLO.png
# Kept 99394_LCC.png as is (positive)
# Kept 99394_LMLO.png as is (positive)
# Kept 99414_LCC.png as is (positive)
# Kept 99414_LMLO.png as is (positive)
# Inverted 99504_RCC.png
# Inverted 99504_RMLO.png
# Inverted 99540_RCC.png
# Inverted 99540_RMLO.png
# Inverted 99660_LCC.png
# Inverted 99660_LMLO.png

# %% [markdown]
# Step.5: Resizing to 512x512

# %%
import os
from PIL import Image

# Paths
input_dir = r"C:\Users\User\Desktop\compitission\3"
output_dir = r"C:\Users\User\Desktop\compitission\4"

# Create output directory if it doesn't exist
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# Function to resize image
def resize_image(image_path, output_path, size=(512, 512)):
    with Image.open(image_path) as img:
        # Resize the image
        img_resized = img.resize(size, Image.Resampling.LANCZOS)
        # Save the resized image
        img_resized.save(output_path)

# Process each image in the input directory
for filename in os.listdir(input_dir):
    if filename.lower().endswith(('.png', '.jpg', '.jpeg', '.bmp', '.gif')):
        input_image_path = os.path.join(input_dir, filename)
        output_image_path = os.path.join(output_dir, filename)

        # Resize and save the image
        resize_image(input_image_path, output_image_path)

print("All images have been resized and saved to the output directory.")
# Out:
# All images have been resized and saved to the output directory.
